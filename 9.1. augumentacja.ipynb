# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization

es = EarlyStopping(monitor = "val_loss", mode = "min", patience = 5)

EPOCHS = 100

# %%
from keras.preprocessing.image import ImageDataGenerator

root_path = "flowers/"

gen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Load Data
train_ds = gen.flow_from_directory(
    root_path,
    class_mode="categorical",
    classes = os.listdir(root_path),
    shuffle=True,
    batch_size=32,
    target_size=(128,128),
    subset="training"
)

valid_ds = gen.flow_from_directory(
    root_path,
    class_mode="categorical",
    classes = os.listdir(root_path),
    shuffle=True,
    batch_size=32,
    target_size=(128,128),
    subset="validation"
)
# Out:
# Found 3457 images belonging to 5 classes.
# Found 860 images belonging to 5 classes.

# %%
classes = os.listdir(root_path)

# %%
classes
# Out:
# ['rose', 'daisy', 'sunflower', 'dandelion', 'tulip']

# %%
plt.figure(figsize=(10,10))
img, label = train_ds.next()
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.imshow(img[i])
    plt.axis('off')
    plt.title(classes[np.argmax(label[i,:])])

# %%
model = Sequential()
model.add(Conv2D(filters =32, kernel_size = (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))
model.summary()

model.compile(optimizer="adam", loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(train_ds, epochs=EPOCHS, validation_data=(valid_ds), callbacks = [es])
# Out:
# 2023-01-03 11:39:09.045886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 125, 125, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 62, 62, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 30, 30, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3,305,669
# Trainable params: 3,305,541
# Non-trainable params: 128
# _________________________________________________________________
# 2023-01-03 11:39:09.195092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:09.195427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:09.197079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-03 11:39:09.198833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:09.199109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:09.199398: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:10.148265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:10.148461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:10.148612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-03 11:39:10.148746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5296 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:41:00.0, compute capability: 6.1
# Epoch 1/100
# 2023-01-03 11:39:12.824194: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8700
# 109/109 [==============================] - 15s 94ms/step - loss: 1.3080 - accuracy: 0.4750 - val_loss: 1.5048 - val_accuracy: 0.3174
# Epoch 2/100
# 109/109 [==============================] - 6s 58ms/step - loss: 1.0579 - accuracy: 0.5725 - val_loss: 1.4647 - val_accuracy: 0.2616
# Epoch 3/100
# 109/109 [==============================] - 6s 57ms/step - loss: 0.8704 - accuracy: 0.6618 - val_loss: 1.5512 - val_accuracy: 0.4070
# Epoch 4/100
# 109/109 [==============================] - 6s 58ms/step - loss: 0.7775 - accuracy: 0.6977 - val_loss: 1.4784 - val_accuracy: 0.4314
# Epoch 5/100
# 109/109 [==============================] - 6s 54ms/step - loss: 0.6390 - accuracy: 0.7590 - val_loss: 1.0412 - val_accuracy: 0.5849
# Epoch 6/100
# 109/109 [==============================] - 6s 58ms/step - loss: 0.6329 - accuracy: 0.7654 - val_loss: 1.1091 - val_accuracy: 0.5907
# Epoch 7/100
# 109/109 [==============================] - 6s 58ms/step - loss: 0.5154 - accuracy: 0.8091 - val_loss: 1.0388 - val_accuracy: 0.6279
# Epoch 8/100
# 109/109 [==============================] - 6s 52ms/step - loss: 0.3877 - accuracy: 0.8554 - val_loss: 1.0207 - val_accuracy: 0.6744
# Epoch 9/100
# 109/109 [==============================] - 6s 58ms/step - loss: 0.4117 - accuracy: 0.8516 - val_loss: 1.1351 - val_accuracy: 0.6651
# Epoch 10/100
# 109/109 [==============================] - 6s 57ms/step - loss: 0.2490 - accuracy: 0.9129 - val_loss: 1.5365 - val_accuracy: 0.6593
# Epoch 11/100
# 109/109 [==============================] - 7s 60ms/step - loss: 0.1533 - accuracy: 0.9497 - val_loss: 1.4893 - val_accuracy: 0.6733
# Epoch 12/100
# 109/109 [==============================] - 6s 57ms/step - loss: 0.1322 - accuracy: 0.9540 - val_loss: 1.9062 - val_accuracy: 0.6267
# Epoch 13/100
# 109/109 [==============================] - 7s 60ms/step - loss: 0.1375 - accuracy: 0.9566 - val_loss: 1.6168 - val_accuracy: 0.6233

# %%
hist = pd.DataFrame(history.history)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(hist.loss, label = "loss")
plt.plot(hist.val_loss, label = "val_loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.accuracy, label = "acc")
plt.plot(hist.val_accuracy, label = "val_acc")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

# %%
gen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=20,
    validation_split=0.2
)

train_ds = gen.flow_from_directory(
    root_path,
    class_mode="categorical",
    classes = os.listdir(root_path),
    shuffle=True,
    batch_size=32,
    target_size=(128,128),
    subset="training"
)

valid_ds = gen.flow_from_directory(
    root_path,
    class_mode="categorical",
    classes = os.listdir(root_path),
    shuffle=True,
    batch_size=32,
    target_size=(128,128),
    subset="validation"
)
# Out:
# Found 3457 images belonging to 5 classes.
# Found 860 images belonging to 5 classes.

# %%
model = Sequential()
model.add(Conv2D(filters =16, kernel_size = (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))
model.summary()

model.compile(optimizer="adam", loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(train_ds, epochs=EPOCHS, validation_data=(valid_ds), callbacks = [es])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 126, 126, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 63, 63, 16)       64
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 30, 30, 32)       128
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_8 (Dense)             (None, 512)               3211776
#
#  dense_9 (Dense)             (None, 128)               65664
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 3,300,549
# Trainable params: 3,300,453
# Non-trainable params: 96
# _________________________________________________________________
# Epoch 1/100
# 109/109 [==============================] - 16s 138ms/step - loss: 1.5218 - accuracy: 0.4345 - val_loss: 1.5448 - val_accuracy: 0.2500
# Epoch 2/100
# 109/109 [==============================] - 15s 136ms/step - loss: 1.1466 - accuracy: 0.5473 - val_loss: 1.5322 - val_accuracy: 0.2930
# Epoch 3/100
# 109/109 [==============================] - 15s 136ms/step - loss: 1.0071 - accuracy: 0.5939 - val_loss: 1.2595 - val_accuracy: 0.4953
# Epoch 4/100
# 109/109 [==============================] - 14s 131ms/step - loss: 0.9498 - accuracy: 0.6263 - val_loss: 1.0393 - val_accuracy: 0.5895
# Epoch 5/100
# 109/109 [==============================] - 15s 136ms/step - loss: 0.9087 - accuracy: 0.6399 - val_loss: 1.0467 - val_accuracy: 0.5802
# Epoch 6/100
# 109/109 [==============================] - 15s 138ms/step - loss: 0.8774 - accuracy: 0.6509 - val_loss: 0.9851 - val_accuracy: 0.6198
# Epoch 7/100
# 109/109 [==============================] - 15s 136ms/step - loss: 0.8361 - accuracy: 0.6749 - val_loss: 0.8661 - val_accuracy: 0.6663
# Epoch 8/100
# 109/109 [==============================] - 15s 138ms/step - loss: 0.7911 - accuracy: 0.6980 - val_loss: 2.1685 - val_accuracy: 0.3779
# Epoch 9/100
# 109/109 [==============================] - 15s 135ms/step - loss: 0.8636 - accuracy: 0.6720 - val_loss: 0.9498 - val_accuracy: 0.6488
# Epoch 10/100
# 109/109 [==============================] - 15s 137ms/step - loss: 0.7575 - accuracy: 0.7023 - val_loss: 0.9060 - val_accuracy: 0.6523
# Epoch 11/100
# 109/109 [==============================] - 14s 130ms/step - loss: 0.7296 - accuracy: 0.7226 - val_loss: 0.9606 - val_accuracy: 0.6407
# Epoch 12/100
# 109/109 [==============================] - 15s 136ms/step - loss: 0.7118 - accuracy: 0.7310 - val_loss: 0.8898 - val_accuracy: 0.6593

# %%
hist = pd.DataFrame(history.history)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(hist.loss, label = "loss")
plt.plot(hist.val_loss, label = "val_loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.accuracy, label = "acc")
plt.plot(hist.val_accuracy, label = "val_acc")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
